# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_excel(r'E:\Study\HIT\Competition\2022-美赛  MCM&ICM\2020_Weekend1_Problems\2020_Weekend1_Problems\2020_Problem_D_DATA\2020_Problem_D_DATA\fullevents1.xlsx')

# %%
df[:5]
# Out:
#    MatchID     TeamID OriginPlayerID DestinationPlayerID MatchPeriod  \
# 0        1    Huskies     Huskies_G1                 NaN          1H
# 1        1  Opponent1   Opponent1_D1                 NaN          1H
# 2        1    Huskies     Huskies_F1                 NaN          1H
# 3        1  Opponent1   Opponent1_D2                 NaN          1H
# 4        1    Huskies     Huskies_D1          Huskies_F1          1H
#
#    EventTime  EventType EventSubType  EventOrigin_x  EventOrigin_y  \
# 0  31.174681  Free Kick    Goal kick            0.0            0.0
# 1  33.730326       Duel     Air duel           34.0           11.0
# 2  33.812965       Duel     Air duel           66.0           89.0
# 3  42.611028  Free Kick     Throw in           22.0            0.0
# 4  46.323501       Pass    Head pass           34.0           97.0
#
#    EventDestination_x  EventDestination_y
# 0                66.0                89.0
# 1                22.0                 0.0
# ...

# %%
s=pd.Series(np.arange(1,10),index=[['a','a','a','b','b','c','c','d','d'],[1,2,3,1,2,3,1,2,3]])#都是9个
s
# Out:
# a  1    1
#    2    2
#    3    3
# b  1    4
#    2    5
# c  3    6
#    1    7
# d  2    8
#    3    9
# dtype: int32

# %%
s.index
# Out:
# MultiIndex([('a', 1),
#             ('a', 2),
#             ('a', 3),
#             ('b', 1),
#             ('b', 2),
#             ('c', 3),
#             ('c', 1),
#             ('d', 2),
#             ('d', 3)],
#            )

# %%
s['a':'b']
# Out:
# a  1    1
#    2    2
#    3    3
# b  1    4
#    2    5
# dtype: int32

# %%
s[:,2]
# Out:
# a    2
# b    5
# d    8
# dtype: int32

# %% [markdown]
# s[:,1:2]不对

# %%
s.unstack()
# Out:
#      1    2    3
# a  1.0  2.0  3.0
# b  4.0  5.0  NaN
# c  7.0  NaN  6.0
# d  NaN  8.0  9.0

# %%
s.unstack().stack()
# Out:
# a  1    1.0
#    2    2.0
#    3    3.0
# b  1    4.0
#    2    5.0
# c  1    7.0
#    3    6.0
# d  2    8.0
#    3    9.0
# dtype: float64

# %%
data=pd.DataFrame(np.arange(12).reshape(4,3),index=[['a','a','b','b',],[1,2,1,2]],columns=[['A','A','B'],['Z','X','C']])
data
# Out:
#      A       B
#      Z   X   C
# a 1  0   1   2
#   2  3   4   5
# b 1  6   7   8
#   2  9  10  11

# %%
data['B']#aZXC报错
# Out:
#       C
# a 1   2
#   2   5
# b 1   8
#   2  11

# %%
data.index.names=['row1','row2']
data.columns.names=['col1','col2']
data
# Out:
# col1       A       B
# col2       Z   X   C
# row1 row2
# a    1     0   1   2
#      2     3   4   5
# b    1     6   7   8
#      2     9  10  11

# %%
data.swaplevel('row1','row2')#调row的位置
# Out:
# col1       A       B
# col2       Z   X   C
# row2 row1
# 1    a     0   1   2
# 2    a     3   4   5
# 1    b     6   7   8
# 2    b     9  10  11

# %%
df.index
# Out:
# RangeIndex(start=0, stop=59271, step=1)

# %%
df=df.set_index(['EventOrigin_x','EventOrigin_y'])
df
# Out:
#                              MatchID      TeamID OriginPlayerID  \
# EventOrigin_x EventOrigin_y
# 0.0           0.0                  1     Huskies     Huskies_G1
# 34.0          11.0                 1   Opponent1   Opponent1_D1
# 66.0          89.0                 1     Huskies     Huskies_F1
# 22.0          0.0                  1   Opponent1   Opponent1_D2
# 34.0          97.0                 1     Huskies     Huskies_D1
# ...                              ...         ...            ...
# 2.0           31.0                38     Huskies     Huskies_D4
# 100.0         100.0               38  Opponent14  Opponent14_M5
# 12.0          53.0                38     Huskies     Huskies_D1
# 88.0          47.0                38  Opponent14  Opponent14_D7
# 86.0          50.0                38  Opponent14  Opponent14_D7
#
#                             DestinationPlayerID MatchPeriod    EventTime  \
# EventOrigin_x EventOrigin_y
# ...

# %%
df.index[1]
# Out:
# (34.0, 11.0)

# %%
df.loc[2.0]
# Out:
#                MatchID      TeamID OriginPlayerID DestinationPlayerID  \
# EventOrigin_y
# 1.0                  2   Opponent2   Opponent2_M4                 NaN
# 87.0                 3     Huskies     Huskies_D6                 NaN
# 23.0                 3     Huskies     Huskies_D4                 NaN
# 8.0                  3   Opponent3   Opponent3_D4                 NaN
# 1.0                  4     Huskies     Huskies_M1                 NaN
# 13.0                 4   Opponent4   Opponent4_D1                 NaN
# 5.0                  4     Huskies     Huskies_F2                 NaN
# 1.0                  4     Huskies     Huskies_M3                 NaN
# 42.0                 4   Opponent4   Opponent4_G1                 NaN
# 87.0                 4   Opponent4   Opponent4_D2                 NaN
# 13.0                 4     Huskies     Huskies_G1                 NaN
# 59.0                 4   Opponent4   Opponent4_D4                 NaN
# ...

# %%
df=df.reset_index()

# %%
data=df[:10]
data
# Out:
#    EventOrigin_x  EventOrigin_y  MatchID     TeamID OriginPlayerID  \
# 0            0.0            0.0        1    Huskies     Huskies_G1
# 1           34.0           11.0        1  Opponent1   Opponent1_D1
# 2           66.0           89.0        1    Huskies     Huskies_F1
# 3           22.0            0.0        1  Opponent1   Opponent1_D2
# 4           34.0           97.0        1    Huskies     Huskies_D1
# 5           59.0           95.0        1    Huskies     Huskies_F1
# 6           41.0            5.0        1  Opponent1   Opponent1_D1
# 7           36.0            6.0        1  Opponent1   Opponent1_M1
# 8           55.0           95.0        1    Huskies     Huskies_F1
# 9           43.0            7.0        1  Opponent1   Opponent1_D1
#
#   DestinationPlayerID MatchPeriod  EventTime  EventType  \
# 0                 NaN          1H  31.174681  Free Kick
# 1                 NaN          1H  33.730326       Duel
# 2                 NaN          1H  33.812965       Duel
# ...

# %%
data.T
# Out:
#                               0             1           2             3  \
# EventOrigin_x               0.0          34.0        66.0          22.0
# EventOrigin_y               0.0          11.0        89.0           0.0
# MatchID                       1             1           1             1
# TeamID                  Huskies     Opponent1     Huskies     Opponent1
# OriginPlayerID       Huskies_G1  Opponent1_D1  Huskies_F1  Opponent1_D2
# DestinationPlayerID         NaN           NaN         NaN           NaN
# MatchPeriod                  1H            1H          1H            1H
# EventTime             31.174681     33.730326   33.812965     42.611028
# EventType             Free Kick          Duel        Duel     Free Kick
# EventSubType          Goal kick      Air duel    Air duel      Throw in
# EventDestination_x         66.0          22.0        78.0          66.0
# EventDestination_y         89.0           0.0       100.0           3.0
#
# ...

# %%
#data.stack().unstack()   转为层次化索引的series

# %%
group=df.groupby(df['EventDestination_x'])

# %%
type(group)
# Out:
# pandas.core.groupby.generic.DataFrameGroupBy

# %%
group.mean()
# Out:
#                     EventOrigin_x  EventOrigin_y    MatchID    EventTime  \
# EventDestination_x
# 0.0                     58.403580      49.340928  18.958503  1515.295114
# 1.0                     14.928571      43.714286  14.476190  1620.408198
# 2.0                     12.168675      39.072289  17.638554  1488.171898
# 3.0                     19.184049      48.245399  18.245399  1437.053437
# 4.0                     16.176101      46.264151  19.452830  1280.277245
# ...                           ...            ...        ...          ...
# 96.0                    84.100000      49.944000  18.436000  1378.197482
# 97.0                    83.936364      49.600000  18.300000  1468.075630
# 98.0                    79.369128      57.926174  17.402685  1394.960928
# 99.0                    78.560976      53.024390  13.975610  1424.041184
# 100.0                   76.963074      50.904192  19.212575  1546.755998
#
#                     EventDestination_y
# EventDestination_x
# ...

# %%
df['EventDestination_y'].groupby(df['EventDestination_x']).median()
# Out:
# EventDestination_x
# 0.0        0.0
# 1.0       29.5
# 2.0       29.0
# 3.0       45.0
# 4.0       46.0
#          ...
# 96.0      51.0
# 97.0      52.5
# 98.0      72.0
# 99.0      70.5
# 100.0    100.0
# Name: EventDestination_y, Length: 101, dtype: float64

# %%
df['EventDestination_y'].groupby([df['EventDestination_x'],df['EventOrigin_y']]).mean()
# Out:
# EventDestination_x  EventOrigin_y
# 0.0                 0.0               22.222222
#                     1.0                0.000000
#                     2.0                0.000000
#                     3.0                3.333333
#                     4.0                0.000000
#                                         ...
# 100.0               96.0              86.666667
#                     97.0             100.000000
#                     98.0              96.250000
#                     99.0             100.000000
#                     100.0             92.111111
# Name: EventDestination_y, Length: 9672, dtype: float64

# %%
pd.cut(df['EventDestination_y'],[-1,25,50,75,100],right=True,labels=['D','C','B','A'])
# Out:
# 0        A
# 1        D
# 2        A
# 3        D
# 4        A
#         ..
# 59266    C
# 59267    C
# 59268    C
# 59269    C
# 59270    D
# Name: EventDestination_y, Length: 59271, dtype: category
# Categories (4, object): ['D' < 'C' < 'B' < 'A']

# %%
bins=np.percentile(df['EventDestination_y'],[0,25,50,75,100])

# %%
#df['EventDestination_x']=pd.cut(df['EventDestination_y'],bins,labels=['D','C','B','A'])

# %%
#df[(df.热门程度==‘E’)&(df。评分等级==‘A’)]

# %% [markdown]
# pd.merge(left, right, how='inner', on=None, left_on=None, right_on=None,
# lef_ index=False, right_index=False, sort=True,
# suffixes=('_x','_y'), copy=True, indicator=False)
# left:对象
# right:另一个对象
# on:要加入的列（名称）。必须在左、右综合对象中找到。如果不能通过 left index和 right_ index是假，将推断 Dataframes中的列的交又点为连接健
# left_on:从左边的综合使用作为键列。可以是列名或数组的长度等于长度综合
# right on:从正确的综合，以用作键列。可以是列名或数组的长度等于长度综合
# left_ index:如果为Tue,则使用素引（行标签）从左综合作为其联接键。在与多重（层次）的综合，级别別数必须匹配联接键从右综合的数目
# right index:相同用法作为正确综合 left index
# how:之ー・左，右，外在、内部。默认为内部。每个方法的更详细说明请参阅：
# sort:综合通过联接键按字典顺序对结果进行排序。默认值为True,设置为 False将提高性能极大地在许多情况下
# suffixes:字符串后缀井不适用于重列的元组。默认值为(_x,'y).
# copy:即使重新索引是不必要总是从传递的综合对象，复制的数据(默认值True)。在许多情况下不能兔，但可能会提高性能/内存使用情况。可以避免复制
# 上述案件有些病理但尽管如此提供此选项。
# indicator:将列添加到输出综合呼吁_ merge与信息源的每一行。_ merge是绝对类型，并对观测其合并键只出现在左的综合，观测其合并键只会出现在'正确
# 的综合，和两个如果观察合并关健发现在两个ight_ only left_ony的值。

# %%
df1=df.loc[:5]
df1
# Out:
#    EventOrigin_x  EventOrigin_y  MatchID     TeamID OriginPlayerID  \
# 0            0.0            0.0        1    Huskies     Huskies_G1
# 1           34.0           11.0        1  Opponent1   Opponent1_D1
# 2           66.0           89.0        1    Huskies     Huskies_F1
# 3           22.0            0.0        1  Opponent1   Opponent1_D2
# 4           34.0           97.0        1    Huskies     Huskies_D1
# 5           59.0           95.0        1    Huskies     Huskies_F1
#
#   DestinationPlayerID MatchPeriod  EventTime  EventType  \
# 0                 NaN          1H  31.174681  Free Kick
# 1                 NaN          1H  33.730326       Duel
# 2                 NaN          1H  33.812965       Duel
# 3                 NaN          1H  42.611028  Free Kick
# 4          Huskies_F1          1H  46.323501       Pass
# 5                 NaN          1H  47.004714       Duel
#
#              EventSubType  EventDestination_x  EventDestination_y
# ...

# %%
df2=df.loc[:5][['EventOrigin_x','EventOrigin_y']]
df2['z']=[1,3,5,7,9,11]
df2
# Out:
#    EventOrigin_x  EventOrigin_y   z
# 0            0.0            0.0   1
# 1           34.0           11.0   3
# 2           66.0           89.0   5
# 3           22.0            0.0   7
# 4           34.0           97.0   9
# 5           59.0           95.0  11

# %%
df2=df2.sample(frac=1)#顺序打乱但index仍对应
df2
# Out:
#    EventOrigin_x  EventOrigin_y   z
# 5           59.0           95.0  11
# 1           34.0           11.0   3
# 2           66.0           89.0   5
# 4           34.0           97.0   9
# 0            0.0            0.0   1
# 3           22.0            0.0   7

# %%
df2.index=range(len(df2))#更改index
df2
# Out:
#    EventOrigin_x  EventOrigin_y   z
# 0           59.0           95.0  11
# 1           34.0           11.0   3
# 2           66.0           89.0   5
# 3           34.0           97.0   9
# 4            0.0            0.0   1
# 5           22.0            0.0   7

# %%
# df2.loc[3,'EventOrigin_y']=97.0
# df2.loc[4,'EventOrigin_y']=10.0
# df2.loc[5,'EventOrigin_y']=10.0
# df2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_22300/3150854883.py in <module>
# ----> 1 df2.loc[3,'EventOrigin_y']=97.0
#       2 df2.loc[4,'EventOrigin_y']=10.0
#       3 df2.loc[5,'EventOrigin_y']=10.0
#       4 df2
#
# AttributeError: 'float' object has no attribute 'loc'

# %%
#index不对应情况下df1和df2合并    用on
pd.merge(df1,df2,how='inner',on='EventOrigin_y')
# Out:
#    EventOrigin_x_x  EventOrigin_y  MatchID     TeamID OriginPlayerID  \
# 0              0.0            0.0        1    Huskies     Huskies_G1
# 1              0.0            0.0        1    Huskies     Huskies_G1
# 2             22.0            0.0        1  Opponent1   Opponent1_D2
# 3             22.0            0.0        1  Opponent1   Opponent1_D2
# 4             34.0           11.0        1  Opponent1   Opponent1_D1
# 5             66.0           89.0        1    Huskies     Huskies_F1
# 6             34.0           97.0        1    Huskies     Huskies_D1
# 7             59.0           95.0        1    Huskies     Huskies_F1
#
#   DestinationPlayerID MatchPeriod  EventTime  EventType  \
# 0                 NaN          1H  31.174681  Free Kick
# 1                 NaN          1H  31.174681  Free Kick
# 2                 NaN          1H  42.611028  Free Kick
# 3                 NaN          1H  42.611028  Free Kick
# 4                 NaN          1H  33.730326       Duel
# ...

# %%
df4=df[:5]
df5=df[10:15]
df6=df[20:25]
df4
# Out:
#    EventOrigin_x  EventOrigin_y  MatchID     TeamID OriginPlayerID  \
# 0            0.0            0.0        1    Huskies     Huskies_G1
# 1           34.0           11.0        1  Opponent1   Opponent1_D1
# 2           66.0           89.0        1    Huskies     Huskies_F1
# 3           22.0            0.0        1  Opponent1   Opponent1_D2
# 4           34.0           97.0        1    Huskies     Huskies_D1
#
#   DestinationPlayerID MatchPeriod  EventTime  EventType EventSubType  \
# 0                 NaN          1H  31.174681  Free Kick    Goal kick
# 1                 NaN          1H  33.730326       Duel     Air duel
# 2                 NaN          1H  33.812965       Duel     Air duel
# 3                 NaN          1H  42.611028  Free Kick     Throw in
# 4          Huskies_F1          1H  46.323501       Pass    Head pass
#
#    EventDestination_x  EventDestination_y
# 0                66.0                89.0
# 1                22.0                 0.0
# ...

# %%
dff=pd.concat([df4,df5,df6])
dff
# Out:
#     EventOrigin_x  EventOrigin_y  MatchID     TeamID OriginPlayerID  \
# 0             0.0            0.0        1    Huskies     Huskies_G1
# 1            34.0           11.0        1  Opponent1   Opponent1_D1
# 2            66.0           89.0        1    Huskies     Huskies_F1
# 3            22.0            0.0        1  Opponent1   Opponent1_D2
# 4            34.0           97.0        1    Huskies     Huskies_D1
# 10           53.0           89.0        1    Huskies     Huskies_M1
# 11           69.0           91.0        1    Huskies     Huskies_F2
# 12           30.0            0.0        1  Opponent1   Opponent1_D2
# 13           65.0          100.0        1    Huskies     Huskies_F1
# 14           19.0           16.0        1  Opponent1   Opponent1_D2
# 20           64.0           37.0        1  Opponent1   Opponent1_M1
# 21           30.0           95.0        1    Huskies     Huskies_D1
# 22           28.0            3.0        1  Opponent1   Opponent1_D1
# ...
